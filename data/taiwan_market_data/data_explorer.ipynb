# %%
import pandas as pd

# %%
global_prices = pd.read_csv("./global_prices.csv")
global_volumes = pd.read_csv("./global_volumes.csv")
insitutional_inverstors = pd.read_csv("./institutional_investors.csv")
margin_trading = pd.read_csv("./margin_trading.csv")
tx_features_night = pd.read_csv("./tx_futures_night.csv")

# %%
tx_features_night.head()
# Out:
#          date futures_id  contract_date     open      max      min    close  \
# 0  2017-05-16         TX         201705  10023.0  10045.0  10020.0  10045.0
# 1  2017-05-17         TX         201705  10007.0  10026.0  10007.0  10021.0
# 2  2017-05-18         TX         201706   9979.0   9995.0   9895.0   9895.0
# 3  2017-05-19         TX         201706   9948.0   9968.0   9922.0   9962.0
# 4  2017-05-22         TX         201706   9930.0   9966.0   9930.0   9960.0
#
#    spread  spread_per  volume  settlement_price  open_interest trading_session
# 0    20.0        0.20    2587               0.0              0    after_market
# 1     0.0        0.00    1636               0.0              0    after_market
# 2   -84.0       -0.84    9404               0.0              0    after_market
# 3    11.0        0.11   10652               0.0              0    after_market
# 4    28.0        0.28    6232               0.0              0    after_market
